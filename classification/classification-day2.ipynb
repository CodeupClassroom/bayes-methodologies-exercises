# %% [markdown]
# Prepare Environment

# %%
import pandas as pd
import numpy as np
import acquire
# import warnings
# warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Acquire Data

# %%
df = acquire.get_titanic_data()

# %% [markdown]
# Summarize
#
# - info
# - describe
# - head/tail
# - value_counts
# - shape
# - isnull

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# passenger_id    891 non-null int64
# survived        891 non-null int64
# pclass          891 non-null int64
# sex             891 non-null object
# age             714 non-null float64
# sibsp           891 non-null int64
# parch           891 non-null int64
# fare            891 non-null float64
# embarked        889 non-null object
# class           891 non-null object
# deck            203 non-null object
# embark_town     889 non-null object
# alone           891 non-null int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
df.describe()
# Out:
#        passenger_id    survived      pclass         age       sibsp  \
# count    891.000000  891.000000  891.000000  714.000000  891.000000
# mean     445.000000    0.383838    2.308642   29.699118    0.523008
# std      257.353842    0.486592    0.836071   14.526497    1.102743
# min        0.000000    0.000000    1.000000    0.420000    0.000000
# 25%      222.500000    0.000000    2.000000   20.125000    0.000000
# 50%      445.000000    0.000000    3.000000   28.000000    0.000000
# 75%      667.500000    1.000000    3.000000   38.000000    1.000000
# max      890.000000    1.000000    3.000000   80.000000    8.000000
#
#             parch        fare       alone
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.602694
# std      0.806057   49.693429    0.489615
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000
# 50%      0.000000   14.454200    1.000000
# 75%      0.000000   31.000000    1.000000
# max      6.000000  512.329200    1.000000

# %%
df.dtypes
# Out:
# passenger_id      int64
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class            object
# deck             object
# embark_town      object
# alone             int64
# dtype: object

# %%
df.shape
# Out:
# (891, 13)

# %%
df.isnull().sum()
# Out:
# passenger_id      0
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          2
# class             0
# deck            688
# embark_town       2
# alone             0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#               count        mean         std   min       25%       50%    75%  \
# passenger_id  891.0  445.000000  257.353842  0.00  222.5000  445.0000  667.5
# survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# pclass        891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# age           714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# sibsp         891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# parch         891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# fare          891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
# alone         891.0    0.602694    0.489615  0.00    0.0000    1.0000    1.0
#
#                    max
# passenger_id  890.0000
# survived        1.0000
# pclass          3.0000
# age            80.0000
# sibsp           8.0000
# parch           6.0000
# fare          512.3292
# alone           1.0000

# %%
# df.age.value_counts(sort=False).sort_index()
df.age.value_counts(bins=10, sort=True)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: age, dtype: int64

# %%
df.embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: embarked, dtype: int64

# %% [markdown]
# Prepare Data
#
# - drop columns
# - fillna
# - split
# - impute mean, mode, median: SimpleImputer
# - integer encoding: LabelEncoder
# - one hot encoding: OneHotEncoder
# - scale

# %%
df.drop(columns=['deck'], inplace=True)

# %%
df.fillna(np.nan, inplace=True)

# %%
train, test = train_test_split(df, train_size=.8, random_state=123)
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# Impute mean, mode, median using SimpleImputer

# %%
train.embarked.value_counts(dropna=False)
# Out:
# S      515
# C      128
# Q       67
# NaN      2
# Name: embarked, dtype: int64

# %%
imp_mode = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

imp_mode.fit(train[['embarked']])

train['embarked'] = imp_mode.transform(train[['embarked']])

test['embarked'] = imp_mode.transform(test[['embarked']])
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
train.embarked.value_counts()
# Out:
# S    517
# C    128
# Q     67
# Name: embarked, dtype: int64

# %%
imp_median = SimpleImputer(missing_values=np.nan, strategy = 'median')
train['age'] = imp_median.fit_transform(train[['age']])
train.age.isnull().sum()
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0

# %% [markdown]
# Encoding
#
# 1. integer encoding
# 1. one hot encoding

# %%
int_encoder = LabelEncoder()
int_encoder.fit(train.embarked)
train.embarked = int_encoder.transform(train.embarked)
# Out:
# /Users/maggiegiust/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
train.embarked.value_counts()
# Out:
# 2    517
# 0    128
# 1     67
# Name: embarked, dtype: int64

# %%
embarked_array = np.array(train.embarked)
embarked_array[0:5]
# Out:
# array([0, 1, 0, 1, 0])

# %%
embarked_array = embarked_array.reshape(len(embarked_array), 1)

# %%
embarked_array
# Out:
# array([[0],
#        [1],
#        [0],
#        [1],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [0],
#        [0],
#        [2],
#        [0],
#        [0],
#        [2],
#        [0],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [1],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [2],
#        [1],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [1],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [0],
#        [1],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [1],
#        [0],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [1],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [1],
#        [1],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [1],
#        [2],
#        [0],
#        [1],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [1],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [0],
#        [0],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [0],
#        [0],
#        [1],
#        [2],
#        [2],
#        [0],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [0],
#        [2],
#        [1],
#        [2],
#        [2],
#        [1]])

# %%
ohe = OneHotEncoder(sparse=False, categories='auto')

# %%
embarked_ohe = ohe.fit_transform(embarked_array)
embarked_ohe

# %%
test.embarked = int_encoder.transform(test.embarked)

# %%
embarked_array = np.array(test.embarked).reshape(len(test.embarked), 1)

# %%
embarked_test_ohe = ohe.transform(embarked_array)

# %%
embarked_test_ohe[0:5]
